# %%
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_community.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

def get_documents_from_web(url):
    loader = WebBaseLoader(url)
    docs = loader.load()

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=20, chunk_overlap=5
    )
    splitDocs = splitter.split_documents(docs)
    #print(len(splitDocs)) # if =1 ，代表沒有分割
    return splitDocs

def creat_chain(docs):
    model = OllamaLLM(model='llama3.2')
    
    # 定義 Prompt 模板
    prompt = ChatPromptTemplate.from_template("""
    回答使用者的問題:
    Context: {context}
    Question : {input}
    """
    )

    #chain = prompt | model
    chain = create_stuff_documents_chain( #從數據中檢索
        llm=model,
        prompt=prompt,
    )

    return chain

docs = get_documents_from_web("https://zhuanlan.zhihu.com/p/651175513")
chain = creat_chain(docs)

response = chain.invoke({
    "input":"什麼是LCEL?",\
    "context":docs,
})
print(response)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 40
#      37 docs = get_documents_from_web("https://zhuanlan.zhihu.com/p/651175513")
#      38 chain = creat_chain(docs)
# ---> 40 response = chain.invoke({
#      41     "input":"什麼是LCEL?",\
#      42 })
#      43 print(response)
#
# File ~/anaconda3/lib/python3.12/site-packages/langchain_core/runnables/base.py:5352, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5346 def invoke(
#    5347     self,
#    5348     input: Input,
#    5349     config: Optional[RunnableConfig] = None,
#    5350     **kwargs: Optional[Any],
#    5351 ) -> Output:
# -> 5352     return self.bound.invoke(
#    5353         input,
#    5354         self._merge_configs(config),
#    5355         **{**self.kwargs, **kwargs},
#    5356     )
#
# ...
