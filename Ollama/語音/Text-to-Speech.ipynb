# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM
from TTS.api import TTS  # 導入 Coqui TTS
from IPython.display import Audio, display

# 初始化模型
model = OllamaLLM(model='llama3.2')

# 建立 Prompt
prompt1 = ChatPromptTemplate.from_template("what is the city {person} is from?")

# 建立 Chain
chain1 = prompt1 | model | StrOutputParser()

# 執行 Chain 並獲取結果
result = chain1.invoke({"person": "Biden"})
print(result)


# 使用 Coqui TTS 朗讀結果
tts = TTS(model_name="tts_models/en/ljspeech/tacotron2-DDC", gpu=False)  # 指定模型
file_path = "/home/yuchi/Artificial_Intelligence_Chatbot/Ollama/語音/output.wav"
tts.tts_to_file(text=result, file_path=file_path)  # 儲存為音檔
tts.tts(result)  # 即時朗讀
display(Audio(sound_file, autoplay=True))
# Out:
# I believe you're referring to Joe Biden, the 46th President of the United States. He was born in Scranton, Pennsylvania, but he grew up in Wilmington, Delaware, and later moved to Claymont, Delaware, where he spent most of his life before entering politics.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio, display
file_path = "/home/yuchi/Artificial_Intelligence_Chatbot/Ollama/語音/output.wav"
display(Audio(file_path, autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
